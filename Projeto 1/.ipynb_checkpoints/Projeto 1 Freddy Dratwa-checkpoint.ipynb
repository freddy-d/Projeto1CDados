# %% [markdown]
# <h1>Projeto 1 Freddy Dratwa - 2C</h1>
#
# <ul>
#     <li>IDH [0-1]</li>
#     <li>Taxa de Emprego(15-24 anos) [%]</li>
#     <li>Índice de Corrupção [0-10]</li>
# </ul>
# <p>Ano: 2005</p>
#
# <p>Pergunta: Há relação entre corrupção e desemprego? Isso de alguma forma tem impacto no IDH de certo país?</p>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
idh=pd.read_excel("idh.xlsx")

idh=idh.loc[:,["HDI",2005]].dropna()
idh=idh.rename(columns={2005:"IDH","HDI":"País"})
idh=idh.set_index("País")

idh.head(5)
# Out:
#                IDH
# País
# Afghanistan  0.340
# Albania      0.721
# Algeria      0.667
# Angola       0.445
# Argentina    0.765

# %%
desemprego=pd.read_excel("emprego.xlsx")

desemprego=desemprego.loc[:,["geo",2005]].dropna()
desemprego=desemprego.rename(columns={2005:"Emprego","geo":"País"})
desemprego=desemprego.set_index("País")

desemprego.head(5)
# Out:
#              Emprego
# País
# Afghanistan     45.9
# Albania         35.5
# Algeria         32.5
# Angola          68.1
# Argentina       40.0

# %%
corrupcao=pd.read_excel("corrupcao.xlsx")

corrupcao=corrupcao.loc[:,["geo",2005]].dropna()
corrupcao=corrupcao.rename(columns={2005:"Corrupção","geo":"País"})
corrupcao=corrupcao.set_index("País")

corrupcao.head(5)
# Out:
#              Corrupção
# País
# Afghanistan        2.5
# Albania            2.4
# Algeria            2.8
# Angola             2.0
# Argentina          2.8

# %%
dataframe=corrupcao.join([desemprego,idh],how="inner")

dataframe.sort_values(["IDH"], ascending=False)
# Out:
#                   Corrupção  Emprego    IDH
# País
# Norway                  8.9     51.5  0.938
# Australia               8.8     63.4  0.918
# United States           7.6     52.4  0.902
# New Zealand             9.6     56.8  0.899
# Ireland                 7.4     46.2  0.898
# Sweden                  9.2     41.1  0.896
# Germany                 8.2     42.7  0.895
# Iceland                 9.7     71.6  0.893
# Canada                  8.4     57.6  0.892
# Switzerland             9.1     59.8  0.890
# Netherlands             8.6     61.8  0.890
# Japan                   7.3     40.7  0.886
# Denmark                 9.5     62.0  0.885
# Finland                 9.6     39.8  0.875
# Israel                  6.3     26.8  0.874
# Belgium                 7.4     26.5  0.873
# France                  7.5     26.7  0.869
# South Korea             5.0     30.8  0.866
# Luxembourg              8.5     25.1  0.865
# Italy                   5.0     25.3  0.861
# Austria                 8.7     53.1  0.860
# Spain                   7.0     40.4  0.857
# Greece                  4.3     25.8  0.856
# United Kingdom          8.6     58.1  0.855
# Czech Republic          4.3     27.4  0.854
# Slovenia                6.1     32.5  0.848
# Singapore               9.4     36.8  0.835
# Malta                   6.6     46.1  0.825
# Estonia                 6.4     28.7  0.821
# Qatar                   5.9     37.0  0.818
# ...                     ...      ...    ...
# Angola                  2.0     68.1  0.445
# Myanmar                 1.8     54.9  0.436
# Papua New Guinea        2.3     54.6  0.435
# Senegal                 3.2     54.5  0.432
# Haiti                   1.8     46.3  0.429
# Nigeria                 1.9     25.1  0.429
# Nepal                   2.5     45.9  0.424
# Yemen                   2.7     21.5  0.422
# Tanzania                2.9     70.3  0.420
# Lesotho                 3.4     42.5  0.417
# Benin                   2.9     60.4  0.409
# Uganda                  2.5     75.7  0.401
# Zambia                  2.6     45.8  0.394
# Gambia                  2.7     54.6  0.384
# Sudan                   2.1     24.6  0.383
# Cote d'Ivoire           1.9     46.2  0.383
# Rwanda                  3.1     65.8  0.376
# Malawi                  2.8     49.1  0.351
# Zimbabwe                2.6     50.0  0.347
# Afghanistan             2.5     45.9  0.340
# Mali                    2.9     35.5  0.319
# Ethiopia                2.2     73.4  0.313
# Chad                    1.7     49.2  0.312
# Sierra Leone            2.4     41.3  0.306
# Burkina Faso            3.4     74.6  0.302
# Liberia                 2.2     56.5  0.300
# Mozambique              2.8     64.6  0.285
# Burundi                 2.3     72.4  0.267
# Niger                   2.4     51.2  0.265
# Congo, Dem. Rep.        2.1     60.6  0.260
#
# [151 rows x 3 columns]

# %%
sns.regplot(dataframe["Corrupção"],dataframe["Emprego"])
# Out:
# C:\Users\Freddy Dratwa\AppData\Local\Programs\Python\Python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(dataframe["IDH"],dataframe["Corrupção"])
# Out:
# C:\Users\Freddy Dratwa\AppData\Local\Programs\Python\Python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(dataframe["IDH"],dataframe["Emprego"])
# Out:
# C:\Users\Freddy Dratwa\AppData\Local\Programs\Python\Python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
